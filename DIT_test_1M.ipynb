# %%
# Импортируем библиотеку
import pandas as pd

# %%
# Загружаем данные в датафрейм
data = pd.read_csv('data_for_test_task.csv', sep=';')
data.head()
# Out:
#    DOCUMENT_ID  LINE_ID                                    COL            VAL
# 0            0        1                            ��_��������              0
# 1            0        1       ���������_�����������������_����     2013-05-27
# 2            0        1  ���������_�����������������_���������  �������������
# 3            0        2       ���������_�����������������_����     2014-08-08
# 4            0        2  ���������_�����������������_���������  �������������

# %%
# Создаем результиирующий датафрейм 
df = data.pivot(index=['DOCUMENT_ID', 'LINE_ID'], columns='COL')
df = df['VAL'].reset_index()
df.columns.name = None
df.head()
# Out:
#    DOCUMENT_ID  LINE_ID ��_��������              ���_����������  \
# 0            0        1           0                  ����������
# 1            0        2         NaN                 �����������
# 2            0        3         NaN                 �����������
# 3            0        4         NaN                 �����������
# 4            0        5         NaN  ��������, ������, ��������
#
#   ���_����������_��� ����_������� �����_��_����������  \
# 0                 80          NaN                 NaN
# 1                 68          NaN                 NaN
# 2                 69          NaN                 NaN
# 3                 70          NaN                 NaN
# 4                 50          NaN                 NaN
#
#   ���������_�����������������_���� ���������_�����������������_���������  \
# 0                       2013-05-27                         �������������
# 1                       2014-08-08                         �������������
# 2                       2015-09-23                         �������������
# 3                       2017-02-11                         �������������
# 4                              NaN                                   NaN
#
#   �����������_������_��_���������� �����������_����������_����  \
# 0                              NaN                  2012-06-02
# 1                              NaN                  2012-12-11
# 2                              NaN                  2013-08-30
# 3                              NaN                  2014-05-13
# 4                              NaN                  2012-12-14
#
#   �����������_����������_���������
# 0                               V1
# 1                               V1
# 2                               V2
# 3                               V3
# 4                               V1

# %%
# Дополняем значениями столбец 'ид_пациента'
df['ид_пациента'] = df['DOCUMENT_ID']
df.head()
# Out:
#    DOCUMENT_ID  LINE_ID ��_��������              ���_����������  \
# 0            0        1           0                  ����������
# 1            0        2         NaN                 �����������
# 2            0        3         NaN                 �����������
# 3            0        4         NaN                 �����������
# 4            0        5         NaN  ��������, ������, ��������
#
#   ���_����������_��� ����_������� �����_��_����������  \
# 0                 80          NaN                 NaN
# 1                 68          NaN                 NaN
# 2                 69          NaN                 NaN
# 3                 70          NaN                 NaN
# 4                 50          NaN                 NaN
#
#   ���������_�����������������_���� ���������_�����������������_���������  \
# 0                       2013-05-27                         �������������
# 1                       2014-08-08                         �������������
# 2                       2015-09-23                         �������������
# 3                       2017-02-11                         �������������
# 4                              NaN                                   NaN
#
#   �����������_������_��_���������� �����������_����������_����  \
# 0                              NaN                  2012-06-02
# 1                              NaN                  2012-12-11
# 2                              NaN                  2013-08-30
# 3                              NaN                  2014-05-13
# 4                              NaN                  2012-12-14
#
#   �����������_����������_���������  ид_пациента
# 0                               V1            0
# 1                               V1            0
# 2                               V2            0
# 3                               V3            0
# 4                               V1            0
